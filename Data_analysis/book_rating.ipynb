# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
pwd
# Out:
# '/Users/attoumassa/DSTI/Python Labs/Project'

# %%
df = pd.read_csv("/Users/attoumassa/DSTI/Python Labs/Project/books.csv",
                 sep=",",on_bad_lines='skip',
                 index_col="bookID")

# %%
df.head(10)
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 9       Unauthorized Harry Potter Book Seven News: "Ha...
# 10           Harry Potter Collection (Harry Potter  #1-6)
# 12      The Ultimate Hitchhiker's Guide: Five Complete...
# 13      The Ultimate Hitchhiker's Guide to the Galaxy ...
# 14      The Hitchhiker's Guide to the Galaxy (Hitchhik...
#
#                            authors  average_rating        isbn         isbn13  \
# bookID
# 1       J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 2       J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# ...

# %%
df.describe()
# Out:
#        average_rating        isbn13     num_pages  ratings_count  \
# count    11123.000000  1.112300e+04  11123.000000   1.112300e+04
# mean         3.934075  9.759880e+12    336.405556   1.794285e+04
# std          0.350485  4.429758e+11    241.152626   1.124992e+05
# min          0.000000  8.987060e+09      0.000000   0.000000e+00
# 25%          3.770000  9.780345e+12    192.000000   1.040000e+02
# 50%          3.960000  9.780582e+12    299.000000   7.450000e+02
# 75%          4.140000  9.780872e+12    416.000000   5.000500e+03
# max          5.000000  9.790008e+12   6576.000000   4.597666e+06
#
#        text_reviews_count
# count        11123.000000
# mean           542.048099
# std           2576.619589
# min              0.000000
# 25%              9.000000
# 50%             47.000000
# 75%            238.000000
# max          94265.000000

# %%
df.isna().sum()
# Out:
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
df.dtypes
# Out:
# title                  object
# authors                object
# average_rating        float64
# isbn                   object
# isbn13                  int64
# language_code          object
#   num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# dtype: object

# %% [markdown]
# # 2. Data Cleaning

# %%
df['publication_date']=pd.to_datetime(df['publication_date'],format="%m/%d/%Y",errors='coerce')
#faire attention au format de la date (mois avant jour dans les données )

# %%
df.dtypes
# Out:
# title                         object
# authors                       object
# average_rating               float64
# isbn                          object
# isbn13                         int64
# language_code                 object
#   num_pages                    int64
# ratings_count                  int64
# text_reviews_count             int64
# publication_date      datetime64[ns]
# publisher                     object
# dtype: object

# %%
df['num_occ'] = df.groupby('title')['title'].transform('count')

# %%
df.groupby('title')['title']

# %%
df.groupby(["authors","language_code"]).mean() #group by authors and laguage_code

# %%
df.groupby(["language_code"]).mean()
# Out:
#                average_rating        isbn13    num_pages  ratings_count  \
# language_code
# ale                  4.360000  9.780345e+12   512.000000     102.000000
# ara                  3.550000  9.789774e+12   349.000000     122.000000
# en-CA                4.025714  9.780914e+12   252.000000    4086.714286
# en-GB                3.923411  9.738672e+12   315.509346    2463.691589
# en-US                3.914659  9.754054e+12   330.439631    3773.906960
# eng                  3.934062  9.759689e+12   336.797373   21570.272564
# enm                  3.873333  9.780310e+12  1060.333333    3233.666667
# fre                  3.971528  9.782231e+12   339.000000    3277.319444
# ger                  3.950101  9.783324e+12   391.979798     234.727273
# gla                  4.470000  9.781582e+12   250.000000      11.000000
# glg                  3.360000  9.788498e+12   741.000000      36.000000
# grc                  3.707273  9.780871e+12   413.363636      52.454545
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11123 entries, 1 to 45641
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               11123 non-null  object
#  1   authors             11123 non-null  object
#  2   average_rating      11123 non-null  float64
#  3   isbn                11123 non-null  object
#  4   isbn13              11123 non-null  int64
#  5   language_code       11123 non-null  object
#  6     num_pages         11123 non-null  int64
#  7   ratings_count       11123 non-null  int64
#  8   text_reviews_count  11123 non-null  int64
#  9   publication_date    11123 non-null  object
#  10  publisher           11123 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.0+ MB

# %%
df.groupby(["authors","language_code"]).mean()
# Out:
#                                                                   average_rating  \
# authors                                            language_code
# A.B. Yehoshua/Hillel Halkin                        en-US                   3.600
# A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky       eng                     3.760
# A.E. Cunningham/Harlan Ellison/Charles F. Mille... eng                     4.150
# A.J. Jacobs                                        eng                     3.760
# A.M. Homes                                         en-US                   3.280
# ...                                                                          ...
# Émile Zola/Henri Mitterand                         fre                     4.060
# Émile Zola/Robert Lethbridge/Elinor Dorday         eng                     4.010
# Émile Zola/Robin Buss/Brian  Nelson                eng                     3.990
# Émile Zola/Roger Pearson                           eng                     4.045
# ...
